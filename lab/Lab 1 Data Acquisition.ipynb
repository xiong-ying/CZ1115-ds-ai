# %% [markdown]
# ---
#
# ### Problem 1 solution

# %%
#Basic Libraries

#Library for Data Acquisition and Preparation
import pandas as pd

#Library for Numeric Computations in Python
import numpy as np

#if put header = None, the first row will be in the table 
csv_data=pd.read_csv('train.csv', header = None)

#Check the first few lines of the data set
csv_data.head()
# Out:
#    0           1         2            3        4       5      6         7   \
# 0  Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape
# 1   1          60        RL           65     8450    Pave    NaN       Reg
# 2   2          20        RL           80     9600    Pave    NaN       Reg
# 3   3          60        RL           68    11250    Pave    NaN       IR1
# 4   4          70        RL           60     9550    Pave    NaN       IR1
#
#             8          9   ...        71      72     73           74       75  \
# 0  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal
# 1          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 2          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 3          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 4          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
#
# ...

# %%
#don't put header, then it will refer to the file and auto generate
csv_data=pd.read_csv('train.csv')
csv_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#find out the data type of this imported csv
type(csv_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#find out the shape of the imported csv
csv_data.shape
# Out:
# (1460, 81)

# %%
#'?' is to get the information of the function
csv_data.info?

# %%
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#will show a statistic result of the dataset
csv_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# type of each varieble
type(csv_data["SalePrice"])
# Out:
# pandas.core.series.Series

# %%
# iloc[] is the function to get specific row from dataframe
csv_data.iloc[9]
# Out:
# Id                   10
# MSSubClass          190
# MSZoning             RL
# LotFrontage          50
# LotArea            7420
#                   ...
# MoSold                1
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        118000
# Name: 9, Length: 81, dtype: object

# %%
# assess the variable "salePrice" for item 9
csv_data.iloc[9]["SalePrice"]
# Out:
# 118000

# %% [markdown]
# ---
#
# ### problem 2 solution

# %%
#Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt   #we only need pyplot
sb.set()

#read data from html, getting all the tables from the html
html_Data = pd.read_html("https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table")

# %%
print("Data type : ", type(html_Data))
print("HTML tables : ", len(html_Data))
# Out:
# Data type :  <class 'list'>
# HTML tables :  6

# %%
#to get the table that we want, from the list
html_Data[1]
# Out:
#                 Rank                         NOC  Gold  Silver  Bronze  Total
# 0                  1         United States (USA)    46      37      38    121
# 1                  2         Great Britain (GBR)    27      23      17     67
# 2                  3                 China (CHN)    26      18      26     70
# 3                  4                Russia (RUS)    19      17      20     56
# 4                  5               Germany (GER)    17      10      15     42
# ..               ...                         ...   ...     ...     ...    ...
# 82                78               Nigeria (NGR)     0       0       1      1
# 83                78              Portugal (POR)     0       0       1      1
# 84                78   Trinidad and Tobago (TTO)     0       0       1      1
# 85                78  United Arab Emirates (UAE)     0       0       1      1
# 86  Totals (86 NOCs)            Totals (86 NOCs)   307     307     359    973
#
# [87 rows x 6 columns]

# %%
# the 5th rows
html_Data[1].iloc[5]
# Out:
# Rank                6
# NOC       Japan (JPN)
# Gold               12
# Silver              8
# Bronze             21
# Total              41
# Name: 5, dtype: object

# %%
# find the first 20 rows
html_Data[1].head(20)
# Out:
#    Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    46      37      38    121
# 1     2  Great Britain (GBR)    27      23      17     67
# 2     3          China (CHN)    26      18      26     70
# 3     4         Russia (RUS)    19      17      20     56
# 4     5        Germany (GER)    17      10      15     42
# 5     6          Japan (JPN)    12       8      21     41
# 6     7         France (FRA)    10      18      14     42
# 7     8    South Korea (KOR)     9       3       9     21
# 8     9          Italy (ITA)     8      12       8     28
# 9    10      Australia (AUS)     8      11      10     29
# 10   11    Netherlands (NED)     8       7       4     19
# 11   12        Hungary (HUN)     8       3       4     15
# 12   13        Brazil (BRA)*     7       6       6     19
# 13   14          Spain (ESP)     7       4       6     17
# 14   15          Kenya (KEN)     6       6       1     13
# ...

# %%
# statistic for the first 20 country
html_Data[1].head(20).describe()
# Out:
#             Gold     Silver    Bronze       Total
# count  20.000000  20.000000  20.00000   20.000000
# mean   12.100000  10.150000  11.35000   33.600000
# std    10.452398   8.797577   9.51052   27.545942
# min     4.000000   2.000000   1.00000   10.000000
# 25%     6.000000   3.000000   4.00000   16.500000
# 50%     8.000000   7.500000   8.50000   21.500000
# 75%    13.250000  13.250000  15.50000   42.000000
# max    46.000000  37.000000  38.00000  121.000000
